# %% [markdown]
# <div style="border:solid lightblue 3px; padding: 20px">
# <b>Юлия, привет!</b>
#
# Меня зовут Виталий Мехоношин, и я буду проверять твой проект. Предлагаю общаться на «ты» 😉
#
# Моя основная цель — не указать на совершенные тобою ошибки, а поделиться своим опытом и помочь тебе стать аналитиком данных. Тобой проделана большая работа над проектом, давай сделаем его еще лучше. Ниже ты найдешь мои комментарии. Есть несколько правил:<br>
# - <b>Пожалуйста, не перемещай, не изменяй и не удаляй комментарии.</b>
# - У комментариев могут быть приписки <b>V2, V3</b> и т.д., которые соответствуют версии проверки.
# - Еще обрати внимание на цветовую разметку:
#
# <div class="alert alert-danger">
# <b>❌ Комментарий ревьюера:</b>
# Комментарии такого цвета необходимо исправить, без их отработки проект не будет принят.
# </div>
#
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьюера:</b>
# На комментарии такого цвета нужно обязательно обратить внимание. Их не должно быть много.
# </div>
#
# <div class="alert alert-success">
# <b>✅ Комментарий ревьюера:</b>
# Комментарии такого цвета будут содержать лайфхаки, которые смогут улучшить твой верный код, их необязательно исправлять.
# </div>
#
# Предлагаю работать над проектом в диалоге: если ты хочешь ответить на мои комментарии — пиши об этом. Мне будет легче отследить изменения, если ты выделишь свои комментарии вот так:
# <div class="alert alert-info"> <b>Комментарий студента:</b> Например, вот так.</div>
#
# Всё это поможет выполнить повторную проверку твоего проекта оперативнее.

# %% [markdown]
# <div style="border:solid lightblue 3px; padding: 20px">
# <b>Общий комментарий ревьюера:</b>
#
# Очень хорошая работа, все пункты выполнены качественно и добросовестно. Мне понравилась подробность твоих рассуждений и четкое подтверждение кодом. Оставил ряд рекомендаций и советов по улучшую кода и проекта в целом. Так же обрати внимание на желтые комменты, над ними желательно поработать. Готов принят работу с первого раза, но рекомендую тебе задать интересующие вопросы, возможно, что-то не получается, и я смогу тебе в этом помочь. Возвращаю тебе проект, чтобы дать такую возможность😊
# </div>

# %% [markdown]
# <div style="border:solid lightblue 3px; padding: 20px">
# <b>Общий комментарий ревьюера V2:</b>
#
# Работа по комментариям успешно произведена, проект принят, удачи на следующих спринтах😊
# </div>

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Изучение-данных-из-файла" data-toc-modified-id="Изучение-данных-из-файла-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Изучение данных из файла</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Изменение-некорректных-названий-столбцов" data-toc-modified-id="Изменение-некорректных-названий-столбцов-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Изменение некорректных названий столбцов</a></span></li><li><span><a href="#Изменение-порядка-следования-столбцов" data-toc-modified-id="Изменение-порядка-следования-столбцов-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Изменение порядка следования столбцов</a></span></li><li><span><a href="#Изменение-единиц-измерения-дистанции" data-toc-modified-id="Изменение-единиц-измерения-дистанции-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Изменение единиц измерения дистанции</a></span></li><li><span><a href="#Обработка-пропусков" data-toc-modified-id="Обработка-пропусков-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Обработка пропусков</a></span><ul class="toc-item"><li><span><a href="#Столбцы-balcony_number,-days_placement" data-toc-modified-id="Столбцы-balcony_number,-days_placement-2.4.1"><span class="toc-item-num">2.4.1&nbsp;&nbsp;</span>Столбцы <code>balcony_number</code>, <code>days_placement</code></a></span></li><li><span><a href="#Столбец-floors_total" data-toc-modified-id="Столбец-floors_total-2.4.2"><span class="toc-item-num">2.4.2&nbsp;&nbsp;</span>Столбец <code>floors_total</code></a></span></li><li><span><a href="#Столбец-locality_name" data-toc-modified-id="Столбец-locality_name-2.4.3"><span class="toc-item-num">2.4.3&nbsp;&nbsp;</span>Столбец <code>locality_name</code></a></span></li><li><span><a href="#Столбец-is_apartment" data-toc-modified-id="Столбец-is_apartment-2.4.4"><span class="toc-item-num">2.4.4&nbsp;&nbsp;</span>Столбец <code>is_apartment</code></a></span></li><li><span><a href="#Столбецceiling_height" data-toc-modified-id="Столбецceiling_height-2.4.5"><span class="toc-item-num">2.4.5&nbsp;&nbsp;</span>Столбец<code>ceiling_height</code></a></span></li><li><span><a href="#Столбцы-airport_nearest_distance,center_distance,-parks_around3,-park_nearest,ponds_around3,-pond_nearest" data-toc-modified-id="Столбцы-airport_nearest_distance,center_distance,-parks_around3,-park_nearest,ponds_around3,-pond_nearest-2.4.6"><span class="toc-item-num">2.4.6&nbsp;&nbsp;</span>Столбцы <code>airport_nearest_distance</code>,<code>center_distance</code>, <code>parks_around3</code>, <code>park_nearest</code>,<code>ponds_around3</code>, <code>pond_nearest</code></a></span></li><li><span><a href="#Столбцыliving_area-и-kitchen_area" data-toc-modified-id="Столбцыliving_area-и-kitchen_area-2.4.7"><span class="toc-item-num">2.4.7&nbsp;&nbsp;</span>Столбцы<code>living_area</code> и <code>kitchen_area</code></a></span></li></ul></li><li><span><a href="#Изменение-форматов-и-типов-данных" data-toc-modified-id="Изменение-форматов-и-типов-данных-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Изменение форматов и типов данных</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Расчёты-и-добавление-результатов-в-таблицу" data-toc-modified-id="Расчёты-и-добавление-результатов-в-таблицу-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Расчёты и добавление результатов в таблицу</a></span><ul class="toc-item"><li><span><a href="#Цена-квадратного-метра" data-toc-modified-id="Цена-квадратного-метра-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Цена квадратного метра</a></span></li><li><span><a href="#День-недели,-месяц-и-год-публикации-объявления" data-toc-modified-id="День-недели,-месяц-и-год-публикации-объявления-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>День недели, месяц и год публикации объявления</a></span></li><li><span><a href="#Этаж-квартиры-(первый,-последний,-другой)" data-toc-modified-id="Этаж-квартиры-(первый,-последний,-другой)-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Этаж квартиры (первый, последний, другой)</a></span></li><li><span><a href="#Соотношение-жилой-и-общей-площади,-отношение-площади-кухни-к-общей" data-toc-modified-id="Соотношение-жилой-и-общей-площади,-отношение-площади-кухни-к-общей-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Соотношение жилой и общей площади, отношение площади кухни к общей</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Изучить-следующие-параметры:-площадь,-цена,-число-комнат,-высота-потолков.-Построить-гистограммы-для-каждого-параметра." data-toc-modified-id="Изучить-следующие-параметры:-площадь,-цена,-число-комнат,-высота-потолков.-Построить-гистограммы-для-каждого-параметра.-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Изучить следующие параметры: площадь, цена, число комнат, высота потолков. Построить гистограммы для каждого параметра.</a></span></li><li><span><a href="#Изучить-время-продажи-квартиры.-Построить-гистограмму.-Посчитать-среднее-и-медиану.-Описать,-сколько-обычно-занимает-продажа.-Когда-можно-считать,-что-продажи-прошли-очень-быстро,-а-когда-необычно-долго?" data-toc-modified-id="Изучить-время-продажи-квартиры.-Построить-гистограмму.-Посчитать-среднее-и-медиану.-Описать,-сколько-обычно-занимает-продажа.-Когда-можно-считать,-что-продажи-прошли-очень-быстро,-а-когда-необычно-долго?-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Изучить время продажи квартиры. Построить гистограмму. Посчитать среднее и медиану. Описать, сколько обычно занимает продажа. Когда можно считать, что продажи прошли очень быстро, а когда необычно долго?</a></span></li><li><span><a href="#Убрать-редкие-и-выбивающиеся-значения.-Описать,-какие-особенности-обнаружены." data-toc-modified-id="Убрать-редкие-и-выбивающиеся-значения.-Описать,-какие-особенности-обнаружены.-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Убрать редкие и выбивающиеся значения. Описать, какие особенности обнаружены.</a></span></li><li><span><a href="#Какие-факторы-больше-всего-влияют-на-стоимость-квартиры?-Изучить,-зависит-ли-цена-от-площади,-числа-комнат,-удалённости-от-центра.-Изучите-зависимость-цены-от-того,-на-каком-этаже-расположена-квартира:-первом,-последнем-или-другом.-Также-изучите-зависимость-от-даты-размещения:-дня-недели,-месяца-и-года." data-toc-modified-id="Какие-факторы-больше-всего-влияют-на-стоимость-квартиры?-Изучить,-зависит-ли-цена-от-площади,-числа-комнат,-удалённости-от-центра.-Изучите-зависимость-цены-от-того,-на-каком-этаже-расположена-квартира:-первом,-последнем-или-другом.-Также-изучите-зависимость-от-даты-размещения:-дня-недели,-месяца-и-года.-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Какие факторы больше всего влияют на стоимость квартиры? Изучить, зависит ли цена от площади, числа комнат, удалённости от центра. Изучите зависимость цены от того, на каком этаже расположена квартира: первом, последнем или другом. Также изучите зависимость от даты размещения: дня недели, месяца и года.</a></span></li><li><span><a href="#Выбрать-10-населённых-пунктов-с-наибольшим-числом-объявлений.-Посчитать-среднюю-цену-квадратного-метра-в-этих-населённых-пунктах.-Выделить-населённые-пункты-с-самой-высокой-и-низкой-стоимостью-жилья.-Эти-данные-можно-найти-по-имени-в-столбце-locality_name." data-toc-modified-id="Выбрать-10-населённых-пунктов-с-наибольшим-числом-объявлений.-Посчитать-среднюю-цену-квадратного-метра-в-этих-населённых-пунктах.-Выделить-населённые-пункты-с-самой-высокой-и-низкой-стоимостью-жилья.-Эти-данные-можно-найти-по-имени-в-столбце-locality_name.-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Выбрать 10 населённых пунктов с наибольшим числом объявлений. Посчитать среднюю цену квадратного метра в этих населённых пунктах. Выделить населённые пункты с самой высокой и низкой стоимостью жилья. Эти данные можно найти по имени в столбце locality_name.</a></span></li><li><span><a href="#Изучить-предложения-квартир:-для-каждой-квартиры-есть-информация-о-расстоянии-до-центра.-Выделить-квартиры-в-Санкт-Петербурге-(locality_name).-Задача-—-выяснить,-какая-область-входит-в-центр.-Создать-столбец-с-расстоянием-до-центра-в-километрах:-округлите-до-целых-значений.-После-этого-посчитать-среднюю-цену-для-каждого-километра.-Построить-график:-он-должен-показывать,-как-цена-зависит-от-удалённости-от-центра.-Определить-границу,-где-график-сильно-меняется,-—-это-и-будет-центральная-зона." data-toc-modified-id="Изучить-предложения-квартир:-для-каждой-квартиры-есть-информация-о-расстоянии-до-центра.-Выделить-квартиры-в-Санкт-Петербурге-(locality_name).-Задача-—-выяснить,-какая-область-входит-в-центр.-Создать-столбец-с-расстоянием-до-центра-в-километрах:-округлите-до-целых-значений.-После-этого-посчитать-среднюю-цену-для-каждого-километра.-Построить-график:-он-должен-показывать,-как-цена-зависит-от-удалённости-от-центра.-Определить-границу,-где-график-сильно-меняется,-—-это-и-будет-центральная-зона.-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>Изучить предложения квартир: для каждой квартиры есть информация о расстоянии до центра. Выделить квартиры в Санкт-Петербурге (locality_name). Задача — выяснить, какая область входит в центр. Создать столбец с расстоянием до центра в километрах: округлите до целых значений. После этого посчитать среднюю цену для каждого километра. Построить график: он должен показывать, как цена зависит от удалённости от центра. Определить границу, где график сильно меняется, — это и будет центральная зона.</a></span></li><li><span><a href="#Выделить-сегмент-квартир-в-центре.-Проанализировать-эту-территорию-и-изучить-следующие-параметры:-площадь,-цена,-число-комнат,-высота-потолков.-Также-выделить-факторы,-которые-влияют-на-стоимость-квартиры-(число-комнат,-этаж,-удалённость-от-центра,-дата-размещения-объявления).-Сделать-выводы.-Отличаются-ли-они-от-общих-выводов-по-всему-городу?" data-toc-modified-id="Выделить-сегмент-квартир-в-центре.-Проанализировать-эту-территорию-и-изучить-следующие-параметры:-площадь,-цена,-число-комнат,-высота-потолков.-Также-выделить-факторы,-которые-влияют-на-стоимость-квартиры-(число-комнат,-этаж,-удалённость-от-центра,-дата-размещения-объявления).-Сделать-выводы.-Отличаются-ли-они-от-общих-выводов-по-всему-городу?-4.7"><span class="toc-item-num">4.7&nbsp;&nbsp;</span>Выделить сегмент квартир в центре. Проанализировать эту территорию и изучить следующие параметры: площадь, цена, число комнат, высота потолков. Также выделить факторы, которые влияют на стоимость квартиры (число комнат, этаж, удалённость от центра, дата размещения объявления). Сделать выводы. Отличаются ли они от общих выводов по всему городу?</a></span></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Общий вывод</a></span></li><li><span><a href="#Чек-лист-готовности-проекта" data-toc-modified-id="Чек-лист-готовности-проекта-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Чек-лист готовности проекта</a></span></li></ul></div>

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В вашем распоряжении данные сервиса Яндекс.Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктах за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости. Ваша задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %% [markdown]
# **Цель исследования**:
# Определять рыночную стоимость объектов недвижимости на основании заданных параметров. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# **Ход исследования**
#  1. Изучение данных из файла
#  2. Предобработка данных
#  3. Расчёты и добавление результатов в таблиц
#  4. Исследовательский анализ данных
#  5. Общий вывод

# %% [markdown]
# ## Изучение данных из файла

# %%
# импорт библиотеки pandas
import pandas as pd
pd.set_option('display.float_format', '{:,.2f}'.format)

# %%
# импорт библиотеки matplotlib
import matplotlib.pyplot as plt

# %%
# импорт библиотеки numpy
import numpy as np

# %%
# чтение файла и сохранение в data
data = pd.read_csv('/datasets/real_estate_data.csv', sep = '\t')

# %%
# просмотр первых 10 строк таблицы
data.head()
# Out:
#    total_images    last_price  total_area first_day_exposition  rooms  \
# 0            20 13,000,000.00      108.00  2019-03-07T00:00:00      3
# 1             7  3,350,000.00       40.40  2018-12-04T00:00:00      1
# 2            10  5,196,000.00       56.00  2015-08-20T00:00:00      2
# 3             0 64,900,000.00      159.00  2015-07-24T00:00:00      3
# 4             2 10,000,000.00      100.00  2018-06-19T00:00:00      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70         16.00        51.00      8          NaN  ...
# 1             nan         11.00        18.60      1          NaN  ...
# 2             nan          5.00        34.30      4          NaN  ...
# 3             nan         14.00          nan      9          NaN  ...
# 4            3.03         14.00        32.00     13          NaN  ...
#
#    kitchen_area  balcony    locality_name  airports_nearest  \
# ...

# %%
# получение общей информации о таблице
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
# total_images            23699 non-null int64
# last_price              23699 non-null float64
# total_area              23699 non-null float64
# first_day_exposition    23699 non-null object
# rooms                   23699 non-null int64
# ceiling_height          14504 non-null float64
# floors_total            23613 non-null float64
# living_area             21796 non-null float64
# floor                   23699 non-null int64
# is_apartment            2775 non-null object
# studio                  23699 non-null bool
# open_plan               23699 non-null bool
# kitchen_area            21421 non-null float64
# balcony                 12180 non-null float64
# locality_name           23650 non-null object
# airports_nearest        18157 non-null float64
# cityCenters_nearest     18180 non-null float64
# parks_around3000        18181 non-null float64
# ...

# %%
# обзор значений столбцов с типами данных int64 и float64
data.describe()
# Out:
#        total_images     last_price  total_area     rooms  ceiling_height  \
# count     23,699.00      23,699.00   23,699.00 23,699.00       14,504.00
# mean           9.86   6,541,548.77       60.35      2.07            2.77
# std            5.68  10,887,013.27       35.65      1.08            1.26
# min            0.00      12,190.00       12.00      0.00            1.00
# 25%            6.00   3,400,000.00       40.00      1.00            2.52
# 50%            9.00   4,650,000.00       52.00      2.00            2.65
# 75%           14.00   6,800,000.00       69.90      3.00            2.80
# max           50.00 763,000,000.00      900.00     19.00          100.00
#
#        floors_total  living_area     floor  kitchen_area   balcony  \
# count     23,613.00    21,796.00 23,699.00     21,421.00 12,180.00
# mean          10.67        34.46      5.89         10.57      1.15
# std            6.60        22.03      4.89          5.91      1.07
# ...

# %% [markdown]
# <div class="alert alert-success">
# <b>✅ Комментарий ревьюера :</b>
#
# Чтобы избавиться от лишних запятых при работе метода `describe` и убрать экспонентациальные формы - пропиши вначале настройку `pandas`, где импортируешь библиотеки.
#
# ```python
# pd.set_option('display.float_format', '{:,.2f}'.format)
# ```
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b>
#
# Привет, Виталий! Спасибо за твои комментарии :) Добавила запись в ячейку.
#
# </div>

# %% [markdown]
# ### Вывод

# %% [markdown]
# В таблице двенадцать два столбца. В столбцах встречается 4 типа данных:
# * `bool` (2 столбца);
# * `int64` (3 столбца);
# * `float64` (14 столбцов);
# * `object` (3 столбца).
#
# Согласно документации к данным:
# * `airports_nearest` — расстояние до ближайшего аэропорта в метрах (м);
# * `balcony` — число балконов;
# * `ceiling_height` — высота потолков (м);
# * `cityCenters_nearest` — расстояние до центра города (м);
# * `days_exposition` — сколько дней было размещено объявление (от публикации до снятия);
# * `first_day_exposition` — дата публикации;
# * `floor` — этаж;
# * `floors_total` — всего этажей в доме;
# * `is_apartment` — апартаменты (булев тип);
# * `kitchen_area` — площадь кухни в квадратных метрах (м²);
# * `last_price` — цена на момент снятия с публикации;
# * `living_area` — жилая площадь в квадратных метрах (м²);
# * `locality_name` — название населённого пункта;
# * `open_plan` — свободная планировка (булев тип);
# * `parks_around3000` — число парков в радиусе 3 км;
# * `parks_nearest` — расстояние до ближайшего парка (м);
# * `ponds_around3000` — число водоёмов в радиусе 3 км;
# * `ponds_nearest` — расстояние до ближайшего водоёма (м);
# * `rooms` — число комнат;
# * `studio` — квартира-студия (булев тип);
# * `total_area` — площадь квартиры в квадратных метрах (м²);
# * `total_images` — число фотографий квартиры в объявлении.
#
# В названиях колонок есть нарушения стиля, но некоторые наименования неточно отражают смысл хранящихся данных.
# Поэтому их стоит переименовать.
#
# Некоторые типы данных лучше сменить для корректности анализа.
#
# Количество значений в столбцах различается. Значит, в данных есть пропущенные значения.

# %% [markdown]
# В каждой строке таблицы — данные с объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктах за несколько лет. Для проверки гипотезы данных достаточно.
# Но в данных есть недочеты и неточности. Ниже перечислены проблемы, найденные в таблице:
#
# - стилистически неверные и неточные названия столбцов;
# - пропуски в ;
# - неудобство восприятия названия столбцов при выводе таблицы;
# - разные единицы измерения площади и длины;
# - в некоторых столбцах тип данных не совпадает со смыслом описываемой переменной;
# - в столбце `first_day_placement` сменить тип данных на datetime;
# - в некоторых столбцах лучше конвертировать величины (столбец о днях трудового стажа).
#
# Перед проверкой гипотезы необходимо устранить указанные проблемы в данных.

# %% [markdown]
# <div class="alert alert-success">
# <b>✅ Комментарий ревьюера :</b>
#
# Первый взгляд на данные хороший.
# </div>

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# ### Изменение некорректных названий столбцов

# %%
# переименовывание названий столбцов методом rename()
data = data.rename(columns = {'airports_nearest': 'airport_nearest_distance',
                             'balcony': 'balcony_number',
                              'cityCenters_nearest': 'center_distance',
                              'days_exposition': 'days_placement',
                              'first_day_exposition': 'first_day_placement',
                              'parks_around3000': 'parks_around3',
                              'parks_nearest': 'park_nearest',
                              'ponds_around3000': 'ponds_around3',
                              'ponds_nearest': 'pond_nearest',
                              'rooms': 'rooms_number',
                              'studio': 'is_studio',
                             'total_images': 'photo_number'})

# %%
# проверка сделанных изменений
data.head()
# Out:
#    photo_number    last_price  total_area  first_day_placement  rooms_number  \
# 0            20 13,000,000.00      108.00  2019-03-07T00:00:00             3
# 1             7  3,350,000.00       40.40  2018-12-04T00:00:00             1
# 2            10  5,196,000.00       56.00  2015-08-20T00:00:00             2
# 3             0 64,900,000.00      159.00  2015-07-24T00:00:00             3
# 4             2 10,000,000.00      100.00  2018-06-19T00:00:00             2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70         16.00        51.00      8          NaN  ...
# 1             nan         11.00        18.60      1          NaN  ...
# 2             nan          5.00        34.30      4          NaN  ...
# 3             nan         14.00          nan      9          NaN  ...
# 4            3.03         14.00        32.00     13          NaN  ...
#
#    kitchen_area  balcony_number    locality_name  airport_nearest_distance  \
# ...

# %% [markdown]
# <div class="alert alert-success">
# <b>✅ Комментарий ревьюера :</b>
#
# Согласен.
# </div>

# %% [markdown]
# ### Изменение порядка следования столбцов

# %% [markdown]
# Столбцы в таблице идут друг за другом хаотично. Необходимо расположить их в алфавитном порядке для удобства восприятия.

# %%
# изменение порядка следования столбцов в таблице
data = data[['airport_nearest_distance', 'balcony_number','ceiling_height','center_distance','days_placement',
          'first_day_placement', 'floor', 'floors_total', 'is_apartment', 'kitchen_area', 'last_price',
           'living_area', 'locality_name', 'open_plan', 'parks_around3', 'park_nearest', 'ponds_around3',
          'pond_nearest', 'rooms_number', 'is_studio', 'total_area', 'photo_number']]

# %%
# проверка сделанных изменений
data.head()
# Out:
#    airport_nearest_distance  balcony_number  ceiling_height  center_distance  \
# 0                 18,863.00             nan            2.70        16,028.00
# 1                 12,817.00            2.00             nan        18,603.00
# 2                 21,741.00            0.00             nan        13,933.00
# 3                 28,098.00            0.00             nan         6,800.00
# 4                 31,856.00             nan            3.03         8,098.00
#
#    days_placement  first_day_placement  floor  floors_total is_apartment  \
# 0             nan  2019-03-07T00:00:00      8         16.00          NaN
# 1           81.00  2018-12-04T00:00:00      1         11.00          NaN
# 2          558.00  2015-08-20T00:00:00      4          5.00          NaN
# 3          424.00  2015-07-24T00:00:00      9         14.00          NaN
# 4          121.00  2018-06-19T00:00:00     13         14.00          NaN
#
# ...

# %%
data['floors_total'].min()
# Out:
# 1.0

# %% [markdown]
# ### Изменение единиц измерения дистанции

# %% [markdown]
# В таблице используются разные единицы измерения расстояния от объекта недвижимости до различных мест (в метрах и километрах). Удобнее перевести все значения в километры.

# %% [markdown]
# ### Обработка пропусков

# %%
# подсчет числа пропусков в каждой колонке
data.isna().sum()
# Out:
# airport_nearest_distance     5542
# balcony_number              11519
# ceiling_height               9195
# center_distance              5519
# days_placement               3181
# first_day_placement             0
# floor                           0
# floors_total                   86
# is_apartment                20924
# kitchen_area                 2278
# last_price                      0
# living_area                  1903
# locality_name                  49
# open_plan                       0
# parks_around3                5518
# park_nearest                15620
# ponds_around3                5518
# pond_nearest                14589
# rooms_number                    0
# is_studio                       0
# total_area                      0
# photo_number                    0
# dtype: int64

# %% [markdown]
# <div class="alert alert-success">
# <b>✅ Комментарий ревьюера :</b>
#
# Полезно так же выводить еще долю пропусков, для этого можешь прописать `mean` вместо `sum`
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Всписала подсчет доли пропусков ниже. </div>

# %%
# доля пропусков
data.isna().mean()
# Out:
# airport_nearest_distance   0.23
# balcony_number             0.49
# ceiling_height             0.39
# center_distance            0.23
# days_placement             0.13
# first_day_placement        0.00
# floor                      0.00
# floors_total               0.00
# is_apartment               0.88
# kitchen_area               0.10
# last_price                 0.00
# living_area                0.08
# locality_name              0.00
# open_plan                  0.00
# parks_around3              0.23
# park_nearest               0.66
# ponds_around3              0.23
# pond_nearest               0.62
# rooms_number               0.00
# is_studio                  0.00
# total_area                 0.00
# photo_number               0.00
# dtype: float64

# %% [markdown]
# #### Столбцы `balcony_number`, `days_placement`

# %% [markdown]
# В 14 колонках из 22 есть пропуски. Их нельзя исключать из таблицы. Некоторые можно заполнить.
# Самое быстрое заполнение пропусков в колонке `balcony_number`. Если значение здесь пропущено, то, вероятнее всего, что балкона нет.
# Также можно заполнить нулями пропуски в столбце `days_placement`. Объявление разместили и в тот же день сняли с публикации.

# %%
# заполнение пропусков в указанных столбцах нулями
columns_to_fill_null = ['balcony_number', 'days_placement']
for column in columns_to_fill_null:
    data[column] = data[column].fillna(0)

# %% [markdown]
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьюера:</b>
#
# Согласен с первыми двумя, но площадь кухни заполнять нулем вряд ли допустимо. Рекомендую использовать зависимость от общей площади. Чаще всего площадь кухни составляет некоторый кф от общей площади, который можно посчитать на основе имеющихся данных.
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Убрала заполнение пропусков в площади кухни. Они обработаны после остальных. </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✅ Комментарий ревьюера V2:</b>
#
# Гуд
# </div>

# %% [markdown]
# #### Столбец `floors_total`

# %% [markdown]
# Возможно человек не вписал общее число этажей потому что квартира находится на максимальном этаже или у дома 1 этаж. Надо проверить это

# %%
# проверка значения этажа
print(data[data.loc[:, 'floors_total'].isna()]['floor'].head())
# Out:
# 186      4
# 237      1
# 457     12
# 671      8
# 1757     9
# Name: floor, dtype: int64

# %% [markdown]
# С учетом предположения, что квартира с пропущенными данными о максимальном этаже дома находится на нем, производится замена с помощью .loc

# %%
# заполнение пропусков значениями этажа
data.loc[data['floors_total'].isna(), 'floors_total'] = data.loc[data['floors_total'].isna(), 'floor']

# %% [markdown]
# <div class="alert alert-success">
# <b>✅ Комментарий ревьюера :</b>
#
# Согласен.
# </div>

# %%
# проверка
data.isna().sum()
# Out:
# airport_nearest_distance     5542
# balcony_number                  0
# ceiling_height               9195
# center_distance              5519
# days_placement                  0
# first_day_placement             0
# floor                           0
# floors_total                    0
# is_apartment                20924
# kitchen_area                 2278
# last_price                      0
# living_area                  1903
# locality_name                  49
# open_plan                       0
# parks_around3                5518
# park_nearest                15620
# ponds_around3                5518
# pond_nearest                14589
# rooms_number                    0
# is_studio                       0
# total_area                      0
# photo_number                    0
# dtype: int64

# %% [markdown]
# #### Столбец `locality_name`

# %% [markdown]
# Пропусков в столбце `locality_name` 49, а всего строк 23699. Такие пропуски ничем не заменить. Их очень мало, поэтому строки с ними стоит удалить.

# %%
# удаление строк с пропусками в "locality_name"
data = data.dropna(subset=['locality_name', ])

# %% [markdown]
# <div class="alert alert-success">
# <b>✅ Комментарий ревьюера :</b>
#
# Да, хорошая оценка, действие корректно.
# </div>

# %% [markdown]
# #### Столбец `is_apartment`

# %% [markdown]
# Очень много пропусков в столбце `is_apartment` (20890 из 23699 строк). Это столбец с булевыми значениями. Их нельзя удалить и заполнить нулями. Но так как эти данные заполнялись людьми, то скорее всего, человек ничего не указывал в случае когда недвижимость не является апартаментами. Необходимо проверить, сколько всего апартаментов.

# %%
# проверка числа явно указанных апартаментов
print('Количество NaN в столбце is_apartment:', data['is_apartment'].isnull().sum())
data['is_apartment'].value_counts()
# Out:
# Количество NaN в столбце is_apartment: 20890
# False    2710
# True       50
# Name: is_apartment, dtype: int64

# %% [markdown]
# Апартаменты отличаются от обычных квартир только оформлением и налогообложением. Возможно поэтому человек не указывал этот параметр. Большей части нет в таблице, поэтому можно заполнить пропуски значениями "False".

# %%
data['is_apartment'] = data['is_apartment'].where(~data['is_apartment'].isnull(), False)

# %% [markdown]
# <div class="alert alert-success">
# <b>✅ Комментарий ревьюера :</b>
#
# Согласен.
#
# </div>

# %% [markdown]
# #### Столбец`ceiling_height`

# %% [markdown]
# На основании постановления Правительства РФ от 28.01.2006 N 47 "Об утверждении Положения о признании помещения жилым помещением" - в жилом помещении минимальная высота потолков составляет 2.1 метр. Необходимо проверить разброс значений в столбце.

# %%
# обзор значений столбца `ceiling_height`
data['ceiling_height'].describe()
# Out:
# count   14,490.00
# mean         2.77
# std          1.26
# min          1.00
# 25%          2.52
# 50%          2.65
# 75%          2.80
# max        100.00
# Name: ceiling_height, dtype: float64

# %% [markdown]
# Минимальное значение - 1 метр. В помещении с такой высотой потолков не сможет жить человек. Проверим сколько всего жилых помещений с высотой потолка менее 2.1 метра.

# %%
# сколько значений менее 2.1
data[(data['ceiling_height'] < 2.1)].shape[0]
# Out:
# 14

# %% [markdown]
# Таких значений мало, можно заменить их на 2.1

# %%
# замена малых и пропущенных значений на 2.1 методом where
data['ceiling_height'] = data['ceiling_height'].where(~((data['ceiling_height'].isnull()) | (data['ceiling_height'] <2.1)),2.1)

# %% [markdown]
# <div class="alert alert-success">
# <b>✅ Комментарий ревьюера :</b>
#
# Да, корректно. Так же можно было заполнить медианой.
#
# </div>

# %% [markdown]
# #### Столбцы `airport_nearest_distance`,`center_distance`, `parks_around3`, `park_nearest`,`ponds_around3`, `pond_nearest`

# %% [markdown]
# В столбцах
# - `airport_nearest_distance`;
# - `center_distance`;
# - `parks_around3`;
# - `park_nearest`;
# - `ponds_around3`;
# - `pond_nearest`
# пропуски можно заменить на медианное значение с разбиением по населенному пункту

# %%
col_names_locality = ['airport_nearest_distance',
                      'center_distance',
                      'parks_around3',
                      'park_nearest',
                      'ponds_around3',
                      'pond_nearest']
for col in col_names_locality:
    for locality_name in data['locality_name'].unique():
        median = data.loc[data['locality_name'] == locality_name, col].median()
        print(locality_name, median)
        data.loc[(data[col].isna()) & (data['locality_name'] == locality_name), col] = median
# Out:
# Санкт-Петербург 26757.5
# посёлок Шушары 17427.0
# городской посёлок Янино-1 nan
# посёлок Парголово 53426.0
# посёлок Мурино nan
# Ломоносов 48415.5
# Сертолово nan
# Петергоф 39231.0
# Пушкин 15766.0
# деревня Кудрово nan
# Коммунар nan
# Колпино 26232.0
# поселок городского типа Красный Бор nan
# Гатчина nan
# поселок Мурино 51553.0
# деревня Фёдоровское nan
# Выборг nan
# Кронштадт 67850.0
# Кировск nan
# деревня Новое Девяткино nan
# посёлок Металлострой 25758.0
# посёлок городского типа Лебяжье nan
# посёлок городского типа Сиверский nan
# поселок Молодцово nan
# поселок городского типа Кузьмоловский nan
# садовое товарищество Новая Ропша nan
# Павловск 20529.5
# деревня Пикколово nan
# Всеволожск nan
# Волхов nan
# Кингисепп nan
# Приозерск nan
# Сестрорецк 56692.0
# деревня Куттузи nan
# посёлок Аннино nan
# /opt/conda/lib/python3.7/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# ...

# %% [markdown]
# <div class="alert alert-success">
# <b>✅ Комментарий ревьюера :</b>
#
# Отлично, с этими столбцами все гуд.
#
# </div>

# %%
for col in col_names_locality:
    print('Пропусков в столбце', col, ':', data[col].isna().sum())
# Out:
# Пропусков в столбце airport_nearest_distance : 5386
# Пропусков в столбце center_distance : 5386
# Пропусков в столбце parks_around3 : 5386
# Пропусков в столбце park_nearest : 5998
# Пропусков в столбце ponds_around3 : 5386
# Пропусков в столбце pond_nearest : 5494

# %% [markdown]
# Остались еще пропуски. Они появились из-за того что для каких-то населенных пунктах вовсе нет данных в этих столбцах. Для заполнения оставшихся пропусков можно использовать медианное значение для всего набора данных.

# %%
# заполнение медианными значениями по всему датасету пропусков в столбцах col_names_locality
col_names_locality = ['airport_nearest_distance',
                      'center_distance',
                      'parks_around3',
                      'park_nearest',
                      'ponds_around3',
                      'pond_nearest']
for col in col_names_locality:
    data.loc[(data[col].isna()), col] = data[col].median()

# %%
# проверка
data.isna().sum()
# Out:
# airport_nearest_distance       0
# balcony_number                 0
# ceiling_height                 0
# center_distance                0
# days_placement                 0
# first_day_placement            0
# floor                          0
# floors_total                   0
# is_apartment                   0
# kitchen_area                2269
# last_price                     0
# living_area                 1898
# locality_name                  0
# open_plan                      0
# parks_around3                  0
# park_nearest                   0
# ponds_around3                  0
# pond_nearest                   0
# rooms_number                   0
# is_studio                      0
# total_area                     0
# photo_number                   0
# dtype: int64

# %% [markdown]
# #### Столбцы`living_area` и `kitchen_area`

# %% [markdown]
# Остались только 2 столбца с пропусками. Можно их заполнить на основании медианного коэффициента отношений площади жилой зоны и кухни к общей площади.

# %%
#for locality_name in data['locality_name'].unique():
#        median = data.loc[data['locality_name'] == locality_name, 'living_area'].median()
#        data.loc[(data['living_area'].isna()) & (data['locality_name'] == locality_name), 'living_area'] = median

# %% [markdown]
# <div class="alert alert-success">
# <b>✅ Комментарий ревьюера :</b>
#
# Отлично, с этими столбцами все гуд.
#
# </div>

# %%
#data.loc[(data['living_area'].isna()), 'living_area'] = data['living_area'].median()

# %% [markdown]
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьюера:</b>
#
# Думаю, что лучше будет сделать тут такой же подход, который описал для заполнения площади кухни, тут такая же зависимость. А зависимость от населенного пункта не совсем качественная, так как квартиры бывает с разным кол-вом комнат, а это принципиально разные площадь.
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Исправила </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✅ Комментарий ревьюера V2:</b>
#
# Гуд
# </div>

# %%
# создание вспомогательных столбцов коэффициентов 
data['coeff_living_total'] = data['living_area']/data['total_area']
data['coeff_kitchen_total'] = data['kitchen_area']/data['total_area']

# %%
# замена пропусков произведением медианного коэффициента по нужной площади на общую площадь
data.loc[(data['living_area'].isna()), 'living_area'] = data['coeff_living_total'].median() * data.loc[(data['living_area'].isna()), 'total_area']
data.loc[(data['kitchen_area'].isna()), 'kitchen_area'] = data['coeff_kitchen_total'].median() * data.loc[(data['kitchen_area'].isna()), 'total_area']

# %%
# проверка
data.isna().sum()
# Out:
# airport_nearest_distance       0
# balcony_number                 0
# ceiling_height                 0
# center_distance                0
# days_placement                 0
# first_day_placement            0
# floor                          0
# floors_total                   0
# is_apartment                   0
# kitchen_area                   0
# last_price                     0
# living_area                    0
# locality_name                  0
# open_plan                      0
# parks_around3                  0
# park_nearest                   0
# ponds_around3                  0
# pond_nearest                   0
# rooms_number                   0
# is_studio                      0
# total_area                     0
# photo_number                   0
# coeff_living_total          1898
# coeff_kitchen_total         2269
# dtype: int64

# %%
# удаление вспомогательных столбцов
del data['coeff_living_total']
del data['coeff_kitchen_total']

# %% [markdown]
# Пропуски устанены

# %% [markdown]
# ### Изменение форматов и типов данных

# %%
# обзор первых 5 строк полученной таблицы
data.head()
# Out:
#    airport_nearest_distance  balcony_number  ceiling_height  center_distance  \
# 0                 18,863.00            0.00            2.70        16,028.00
# 1                 12,817.00            2.00            2.10        18,603.00
# 2                 21,741.00            0.00            2.10        13,933.00
# 3                 28,098.00            0.00            2.10         6,800.00
# 4                 31,856.00            0.00            3.03         8,098.00
#
#    days_placement  first_day_placement  floor  floors_total is_apartment  \
# 0            0.00  2019-03-07T00:00:00      8         16.00        False
# 1           81.00  2018-12-04T00:00:00      1         11.00        False
# 2          558.00  2015-08-20T00:00:00      4          5.00        False
# 3          424.00  2015-07-24T00:00:00      9         14.00        False
# 4          121.00  2018-06-19T00:00:00     13         14.00        False
#
# ...

# %%
# обзор данных полученной таблицы
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23650 entries, 0 to 23698
# Data columns (total 22 columns):
# airport_nearest_distance    23650 non-null float64
# balcony_number              23650 non-null float64
# ceiling_height              23650 non-null float64
# center_distance             23650 non-null float64
# days_placement              23650 non-null float64
# first_day_placement         23650 non-null object
# floor                       23650 non-null int64
# floors_total                23650 non-null float64
# is_apartment                23650 non-null object
# kitchen_area                23650 non-null float64
# last_price                  23650 non-null float64
# living_area                 23650 non-null float64
# locality_name               23650 non-null object
# open_plan                   23650 non-null bool
# parks_around3               23650 non-null float64
# park_nearest                23650 non-null float64
# ...

# %% [markdown]
# Значения в столбцах `airport_nearest_distance`, `balcony_number`, `center_distance`, `days_placement`, `floors_total`, `is_apartment`, `last_price`, `parks_around3`, `park_nearest`, `ponds_around3`, `pond_nearest`, записаны в формате float64, их лучше округлить до целых, записав в формате int64 для избавления дробной части и удобства восприятия последующих расчетов.

# %%
# замена типов данных в некоторых столбцах
data = data.astype({'airport_nearest_distance':'int',
                    'balcony_number':'int',
                    'center_distance':'int',
                    'days_placement':'int',
                    'floors_total':'int',
                    'is_apartment':'bool',
                    'last_price':'int',
                    'parks_around3':'int',
                    'park_nearest':'int',
                    'ponds_around3':'int',
                    'pond_nearest':'int'})

# %% [markdown]
# Тип данных столбца `first_day_placement` надо заменить на datetime.

# %%
# изменение формата на datetime
data['first_day_placement'] = pd.to_datetime(data['first_day_placement'],
                                            format = '%Y-%m-%dT%H:%M:%S')

# %%
# приведение названий населенных пунктов к нижнему регистру
data['locality_name'] = data['locality_name'].str.lower()

# %% [markdown]
# В конце нужно проверить на наличие дубликатов

# %%
# проверка на дубликаты
data.duplicated().sum()
# Out:
# 0

# %%
# итоговая проверка
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23650 entries, 0 to 23698
# Data columns (total 22 columns):
# airport_nearest_distance    23650 non-null int64
# balcony_number              23650 non-null int64
# ceiling_height              23650 non-null float64
# center_distance             23650 non-null int64
# days_placement              23650 non-null int64
# first_day_placement         23650 non-null datetime64[ns]
# floor                       23650 non-null int64
# floors_total                23650 non-null int64
# is_apartment                23650 non-null bool
# kitchen_area                23650 non-null float64
# last_price                  23650 non-null int64
# living_area                 23650 non-null float64
# locality_name               23650 non-null object
# open_plan                   23650 non-null bool
# parks_around3               23650 non-null int64
# park_nearest                23650 non-null int64
# ponds_around3               23650 non-null int64
# ...

# %%
# обзор первых 5 строк таблицы
data.head()
# Out:
#    airport_nearest_distance  balcony_number  ceiling_height  center_distance  \
# 0                     18863               0            2.70            16028
# 1                     12817               2            2.10            18603
# 2                     21741               0            2.10            13933
# 3                     28098               0            2.10             6800
# 4                     31856               0            3.03             8098
#
#    days_placement first_day_placement  floor  floors_total  is_apartment  \
# 0               0          2019-03-07      8            16         False
# 1              81          2018-12-04      1            11         False
# 2             558          2015-08-20      4             5         False
# 3             424          2015-07-24      9            14         False
# 4             121          2018-06-19     13            14         False
#
# ...

# %% [markdown]
# ### Вывод

# %% [markdown]
# Пропуски в таблице заполнены на основе медиан групп, к которым относится та или иная ячейка с пропуском. Пропуски в этих столбцах
# появились из-за человеческого фактора или технических сбоев в автоматическом внесении системой сведений об объекте (расстояние до ближайшего пруда, растояние до центра города).
# В дальнейшем необходимо спрашивать тех, кто предоставил данные для
# анализа о возможных причинах пропуска значений в столбцах.

# %% [markdown]
# <div class="alert alert-success">
# <b>✅ Комментарий ревьюера :</b>
#
# Работа над типами данных корректна.
#
# </div>

# %% [markdown]
# ## Расчёты и добавление результатов в таблицу

# %% [markdown]
# Перед проведением исследовательского анализа данных нужно добавить дополнительные столбцы со значениями, которые понадобятся для работы.

# %% [markdown]
# ### Цена квадратного метра

# %%
data['price_per_meter'] = data['last_price']/data['total_area']

# %% [markdown]
# ### День недели, месяц и год публикации объявления

# %%
# добавление дня недели, месяца и года публикации объявления в отдельные столбцы таблицы
data['weekday_placement'] = data['first_day_placement'].dt.weekday
data['month_placement'] = data['first_day_placement'].dt.month
data['year_placement'] = data['first_day_placement'].dt.year

# %% [markdown]
# ### Этаж квартиры (первый, последний, другой)

# %%
# определение функции разбиения значений этажа по 3 категориям (первый, последний, другой)
def floor_category(row):
    if row['floor'] == 1:
        return 'первый'
    elif row['floors_total'] == row['floor']:
        return 'последний'
    else:
        return 'другой'

# %%
# применение функции floor_category
data['floor_cat'] = data.apply(floor_category,axis = 1)

# %% [markdown]
# ### Соотношение жилой и общей площади, отношение площади кухни к общей

# %%
data['living_total_ratio'] = data['living_area']/data['total_area']
data['kitchen_total_ratio'] = data['kitchen_area']/data['total_area']

# %%
# обзор значений полученных столбцов
data.head()
# Out:
#    airport_nearest_distance  balcony_number  ceiling_height  center_distance  \
# 0                     18863               0            2.70            16028
# 1                     12817               2            2.10            18603
# 2                     21741               0            2.10            13933
# 3                     28098               0            2.10             6800
# 4                     31856               0            3.03             8098
#
#    days_placement first_day_placement  floor  floors_total  is_apartment  \
# 0               0          2019-03-07      8            16         False
# 1              81          2018-12-04      1            11         False
# 2             558          2015-08-20      4             5         False
# 3             424          2015-07-24      9            14         False
# 4             121          2018-06-19     13            14         False
#
# ...

# %% [markdown]
# ### Вывод

# %% [markdown]
# Добавлены новые столбцы со значениями, которые потребуются для исследовательского анализа данных

# %% [markdown]
# <div class="alert alert-success">
# <b>✅ Комментарий ревьюера :</b>
#
# Согласен, данные добавлены корректно.
#
# </div>

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# Для построения графиков используется plot() библиотеки matplotlib, так как он переводит большие значения в логарифмический формат. Так удобнее наблюдать числовое распределение.

# %% [markdown]
# ### Изучить следующие параметры: площадь, цена, число комнат, высота потолков. Построить гистограммы для каждого параметра.

# %%
data['total_area'].describe()
# Out:
# count   23,650.00
# mean        60.33
# std         35.66
# min         12.00
# 25%         40.00
# 50%         52.00
# 75%         69.70
# max        900.00
# Name: total_area, dtype: float64

# %%
data.plot(y = 'total_area', kind = 'hist', bins = 100, grid=True, figsize = (5,3), range = (0,500))

# %% [markdown]
# Больше всего продаваемых квартир в наборе имеют площадь 40-50 метров.

# %%
data['last_price'].describe()
# Out:
# count        23,650.00
# mean      6,541,126.90
# std      10,896,399.18
# min          12,190.00
# 25%       3,400,000.00
# 50%       4,650,000.00
# 75%       6,799,000.00
# max     763,000,000.00
# Name: last_price, dtype: float64

# %%
data.plot(y = 'last_price', kind = 'hist', bins = 100, grid=True, range = (0,20000000))

# %% [markdown]
# Распределение напоминает нормальное

# %%
data['rooms_number'].describe()
# Out:
# count   23,650.00
# mean         2.07
# std          1.08
# min          0.00
# 25%          1.00
# 50%          2.00
# 75%          3.00
# max         19.00
# Name: rooms_number, dtype: float64

# %%
data.plot(y = 'rooms_number', kind = 'hist', bins = 30, grid=True)

# %% [markdown]
# Большинство квартир являются 1-комнатными или 2-комнатными

# %%
data['ceiling_height'].describe()
# Out:
# count   23,650.00
# mean         2.51
# std          1.04
# min          2.10
# 25%          2.10
# 50%          2.50
# 75%          2.70
# max        100.00
# Name: ceiling_height, dtype: float64

# %%
data.plot(y = 'ceiling_height', kind = 'hist', bins = 30, range = (2,5), grid=True, figsize = (5,3))

# %% [markdown]
# Основная масса квартир имеет потолки до 2.6 метров, но так же встречаются и помещения с очень высокими потолками

# %% [markdown]
# <div class="alert alert-success">
# <b>✅ Комментарий ревьюера :</b>
#
# Хорошие графики, так же прочитаны они верно, молодец.
#
#
# </div>

# %% [markdown]
# ### Изучить время продажи квартиры. Построить гистограмму. Посчитать среднее и медиану. Описать, сколько обычно занимает продажа. Когда можно считать, что продажи прошли очень быстро, а когда необычно долго?

# %%
# построение гистограммы методом .hist() библиотеки pandas
data['days_placement'].hist(bins = 10,figsize = (15,5))
plt.title('days_placement')
plt.xlabel('days_number')
plt.ylabel('frequency')
plt.show()

# %% [markdown]
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьюера:</b>
#
# Добавь пожалуйста заголовок, подписи осей, легенду где требуется на все свои графики.
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Ок) </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✅ Комментарий ревьюера V2:</b>
#
# Гуд
# </div>

# %%
# обзор значений
data['days_placement'].describe()
# Out:
# count   23,650.00
# mean       156.45
# std        213.56
# min          0.00
# 25%         22.00
# 50%         73.00
# 75%        198.00
# max      1,580.00
# Name: days_placement, dtype: float64

# %% [markdown]
# *Вывод:* Медиана-73, а среднее-156. Обычно объявление закрывается за 73 дня. За пограничные значения в этом случае можно взять границы квартилей. То есть продажа осуществилась быстро, если прошло менее 22 дня с момента публикации объявления. Если же прошло более 198 дней, то продажа оказалась необычно долгой.

# %% [markdown]
# ### Убрать редкие и выбивающиеся значения. Описать, какие особенности обнаружены.

# %% [markdown]
# Удалять выбросы целесообразно основываясь на квартилях.

# %%
# определение функции очистки столбца от выбросов
def remove_fakes(column,data):
    q25=np.array(data[column].describe(percentiles=[.25,.75]).loc['25%'])
    q75=np.array(data[column].describe(percentiles=[.25,.75]).loc['75%'])
    first_part=q25-1.5*(q75-q25)
    second_part=q75+1.5*(q75-q25)
    count = 0
    leng = 1
    while leng > 0:
        index_del= []
        for index, element in enumerate(data[column]):
            if first_part > element or second_part< element:
                index_del.extend(data[data[column] == element].index)

        index_del= set(index_del)
        leng = len(index_del)
        count += 1
        print('Количество строк, выбранных для удаления: {}'.format(leng))
        print(leng)
        data.drop(index_del,axis=0,inplace=True)

# %% [markdown]
# <div class="alert alert-success">
# <b>✅ Комментарий ревьюера :</b>
#
# С отбором выбросов согласен.
#
#
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b>
#
# Виталий, я хотела бы узнать у тебя как можно избавиться от выбросов изящнее, чем такой сложной функцией. Мне с ней помогли :)
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✅ Комментарий ревьюера V2:</b>
#
# По сути такая сложная реально ни к чему. Тебе самое главное что нужно - это определить пороговые значения, как раз это `first_part` и `second_part`. Все что вне этих пределов можешь удалять, вот теперь, попробуй это реализовать)
# </div>

# %%
remove_fakes('total_area', data)
# Out:
# Количество строк, выбранных для удаления: 1244
# 1244
# Количество строк, выбранных для удаления: 0
# 0

# %%
remove_fakes('last_price', data)
# Out:
# Количество строк, выбранных для удаления: 1330
# 1330
# Количество строк, выбранных для удаления: 0
# 0

# %%
remove_fakes('ceiling_height', data)
# Out:
# Количество строк, выбранных для удаления: 200
# 200
# Количество строк, выбранных для удаления: 0
# 0

# %%
remove_fakes('days_placement',data)
# Out:
# Количество строк, выбранных для удаления: 1790
# 1790
# Количество строк, выбранных для удаления: 0
# 0

# %%
remove_fakes('rooms_number', data)
# Out:
# Количество строк, выбранных для удаления: 0
# 0

# %%
# обзор скорректированных значений
data.head()
# Out:
#    airport_nearest_distance  balcony_number  ceiling_height  center_distance  \
# 1                     12817               2            2.10            18603
# 4                     31856               0            3.03             8098
# 5                     26757               0            2.10            13107
# 6                     52996               1            2.10            19143
# 7                     23982               2            2.10            11634
#
#    days_placement first_day_placement  floor  floors_total  is_apartment  \
# 1              81          2018-12-04      1            11         False
# 4             121          2018-06-19     13            14         False
# 5              55          2018-09-10      5            12         False
# 6             155          2017-11-02      6            26         False
# 7               0          2019-04-18     22            24         False
#
# ...

# %%
# обзор значений
data.describe().astype('int')
# Out:
#        airport_nearest_distance  balcony_number  ceiling_height  \
# count                     19086           19086           19086
# mean                      28548               0               2
# std                       11442               0               0
# min                           0               0               2
# 25%                       20745               0               2
# 50%                       26757               0               2
# 75%                       35055               1               2
# max                       84853               5               3
#
#        center_distance  days_placement  floor  floors_total  kitchen_area  \
# count            19086           19086  19086         19086         19086
# mean             14754             100      5            10             9
# std               7298             105      4             6             3
# min                287               0      1             1             1
# ...

# %% [markdown]
# *Вывод:* Общее количество строк стало равным 19086 (прежнее значение-около 23000). Зато данные очищены от выбросов.

# %% [markdown]
# ### Какие факторы больше всего влияют на стоимость квартиры? Изучить, зависит ли цена от площади, числа комнат, удалённости от центра. Изучите зависимость цены от того, на каком этаже расположена квартира: первом, последнем или другом. Также изучите зависимость от даты размещения: дня недели, месяца и года.

# %%
print(data[['total_area','rooms_number','floor_cat','center_distance','last_price']].corr())
# Out:
#                  total_area  rooms_number  center_distance  last_price
# total_area             1.00          0.81            -0.07        0.67
# rooms_number           0.81          1.00            -0.04        0.42
# center_distance       -0.07         -0.04             1.00       -0.19
# last_price             0.67          0.42            -0.19        1.00

# %% [markdown]
# <div class="alert alert-success">
# <b>✅ Комментарий ревьюера :</b>
#
# Отлично, рекомендую подкрашивать эту матрицу с помощью метода `style`.
#
#
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b>
#
# Как добавить метод style?
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✅ Комментарий ревьюера V2:</b>
#
# Можешь посчитать [тут](https://towardsdatascience.com/style-pandas-dataframe-like-a-master-6b02bf6468b0)
# </div>

# %%
pd.plotting.scatter_matrix(data[['total_area','rooms_number','floor_cat','center_distance','last_price']],figsize=(15,15))
plt.show()

# %% [markdown]
# <div class="alert alert-success">
# <b>✅ Комментарий ревьюера :</b>
#
# Хорошо, только чтобы не было выводы странных символов, можешь прописывать в конце `plt.show()`
#
#
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b>
#
# Сделано
#
# </div>

# %% [markdown]
# Цена частично коррелирует только с общей площадью (коэффициент корреляции - 0.672831). Также немного зависит от количества комнат (0.424373). С остальными переменными не связана.

# %%
print(data[['floor_cat','weekday_placement','month_placement','year_placement', 'last_price']].corr())
# Out:
#                    weekday_placement  month_placement  year_placement  \
# weekday_placement               1.00             0.01           -0.01
# month_placement                 0.01             1.00           -0.31
# year_placement                 -0.01            -0.31            1.00
# last_price                     -0.01            -0.00            0.04
#
#                    last_price
# weekday_placement       -0.01
# month_placement         -0.00
# year_placement           0.04
# last_price               1.00

# %%
pd.plotting.scatter_matrix(data[['floor_cat','weekday_placement','month_placement','year_placement', 'last_price']],figsize=(15,15))
plt.show()

# %% [markdown]
# На основании коэффициентов корреляции и графиков зависимости цены от указанных параметров, цена не зависит от даты (дня недели, месяца, года)

# %% [markdown]
# <div class="alert alert-success">
# <b>✅ Комментарий ревьюера :</b>
#
# Зависимости описаны корректно.
# </div>

# %% [markdown]
# ### Выбрать 10 населённых пунктов с наибольшим числом объявлений. Посчитать среднюю цену квадратного метра в этих населённых пунктах. Выделить населённые пункты с самой высокой и низкой стоимостью жилья. Эти данные можно найти по имени в столбце locality_name.

# %%
# построение сводной таблицы для 10 населенных пунктоов с наибольшим числом объявлений
locality_pivot_table = data.pivot_table(index = 'locality_name', values = 'price_per_meter', aggfunc=['count', 'mean'])
locality_pivot_table.columns = ['count', 'mean']
locality_pivot_table = locality_pivot_table.sort_values('count', ascending = False).head()

# %%
display(locality_pivot_table)
# Out:
#                  count       mean
# locality_name
# санкт-петербург  11998 104,955.89
# посёлок мурино     478  85,984.66
# посёлок шушары     405  78,679.19
# всеволожск         348  67,025.36
# колпино            313  75,163.71

# %%
# самая высокая стоимость
locality_pivot_table[locality_pivot_table['mean']==locality_pivot_table['mean'].max()]
# Out:
#                  count       mean
# locality_name
# санкт-петербург  11998 104,955.89

# %%
# самая низкая стоимость
locality_pivot_table[locality_pivot_table['mean']==locality_pivot_table['mean'].min()]
# Out:
#                count      mean
# locality_name
# всеволожск       348 67,025.36

# %% [markdown]
# *Вывод:* На основании исследуемого набора данных - самая высокая стоимость жилья в Санкт-Петербурге, самая низкая - в Всеволожске.

# %% [markdown]
# <div class="alert alert-success">
# <b>✅ Комментарий ревьюера :</b>
#
# Расчеты верны.
# </div>

# %% [markdown]
# ### Изучить предложения квартир: для каждой квартиры есть информация о расстоянии до центра. Выделить квартиры в Санкт-Петербурге (locality_name). Задача — выяснить, какая область входит в центр. Создать столбец с расстоянием до центра в километрах: округлите до целых значений. После этого посчитать среднюю цену для каждого километра. Построить график: он должен показывать, как цена зависит от удалённости от центра. Определить границу, где график сильно меняется, — это и будет центральная зона.

# %%
data['center_distance_km'] = data['center_distance']/1000
data['center_distance_km'] = data['center_distance_km'].fillna(999999)
data['center_distance_km'] = data['center_distance_km'].astype('int')
pivot_table_km = data.query('locality_name == "санкт-петербург" and center_distance_km !=999999').pivot_table(index = 'center_distance_km', values = 'price_per_meter', aggfunc = 'mean')

# %%
pivot_table_km.plot()

# %%
pivot_table_km.head()
# Out:
#                     price_per_meter
# center_distance_km
# 0                        119,601.99
# 1                        118,179.07
# 2                        114,225.27
# 3                        111,206.63
# 4                        119,405.12

# %% [markdown]
# *Вывод:* График сильно меняется на расстоянии от центра, равном 4 километра. Значит это является центральной зоной.

# %% [markdown]
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьюера:</b>
#
# График построен корректно, только на 4 км есть скачок, но не тот. Тебе нужен экстремум, после которого начинается падение цены. Обрати внимание на зону 6-7 км.
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b>Поняла. На основании данных-радиус центрального района-6-7 километров. Далее изменила 4 на 6.</div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✅ Комментарий ревьюера V2:</b>
#
# Отлично.
# </div>

# %% [markdown]
# ### Выделить сегмент квартир в центре. Проанализировать эту территорию и изучить следующие параметры: площадь, цена, число комнат, высота потолков. Также выделить факторы, которые влияют на стоимость квартиры (число комнат, этаж, удалённость от центра, дата размещения объявления). Сделать выводы. Отличаются ли они от общих выводов по всему городу?

# %%
# радиус центрального района принят за 6 километра
data_center = data.query('center_distance_km <= 6 and locality_name == "санкт-петербург"')

# %%
# информация о датасете data_center
data_center.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1536 entries, 24 to 23690
# Data columns (total 30 columns):
# airport_nearest_distance    1536 non-null int64
# balcony_number              1536 non-null int64
# ceiling_height              1536 non-null float64
# center_distance             1536 non-null int64
# days_placement              1536 non-null int64
# first_day_placement         1536 non-null datetime64[ns]
# floor                       1536 non-null int64
# floors_total                1536 non-null int64
# is_apartment                1536 non-null bool
# kitchen_area                1536 non-null float64
# last_price                  1536 non-null int64
# living_area                 1536 non-null float64
# locality_name               1536 non-null object
# open_plan                   1536 non-null bool
# parks_around3               1536 non-null int64
# park_nearest                1536 non-null int64
# ponds_around3               1536 non-null int64
# ...

# %%
data['total_area'].describe()
# Out:
# count   19,086.00
# mean        51.66
# std         16.99
# min         12.00
# 25%         38.50
# 50%         48.00
# 75%         62.00
# max        114.20
# Name: total_area, dtype: float64

# %%
data_center.plot(y = 'total_area', kind = 'hist', bins = 100, grid=True, figsize = (5,3), range = (0,150))

# %% [markdown]
# Общая площадь преимущественно находится в диапазоне от 40 до 60 квадратных метров.

# %%
data_center['last_price'].describe().astype('int')
# Out:
# count        1536
# mean      7002725
# std       1894296
# min       1600000
# 25%       5600000
# 50%       6990000
# 75%       8500000
# max      10700000
# Name: last_price, dtype: int64

# %%
data_center.plot(y = 'last_price', kind = 'hist', bins = 100, grid=True, figsize = (5,3), range = (0,20000000))

# %% [markdown]
# Распределение также похоже на нормальное, как и в общей выборке. Но уже без выбросов.

# %%
data_center['rooms_number'].describe().astype('int')
# Out:
# count    1536
# mean        2
# std         0
# min         0
# 25%         2
# 50%         2
# 75%         3
# max         6
# Name: rooms_number, dtype: int64

# %%
data_center.plot(y = 'rooms_number', kind = 'hist', bins = 10, grid=True, figsize = (5,3), range = (0,10))

# %% [markdown]
# Количество комнат также чаще всего в диапазоне от 2 до 4, как и в выборке по всей Ленинградской области.

# %%
data_center['ceiling_height'].describe().astype('int')
# Out:
# count    1536
# mean        2
# std         0
# min         2
# 25%         2
# 50%         2
# 75%         3
# max         3
# Name: ceiling_height, dtype: int64

# %%
data_center.plot(y = 'ceiling_height', kind = 'hist', bins = 100, grid=True, figsize = (5,3), range = (2,4))

# %% [markdown]
# Объектов с высотой потолков до 2.2 метров значительно больше, чем остальных, в отличие от выборке по всем данным.
# Но также на графике более выражены значения 3 метра и 3.2.

# %%
print(data_center[['rooms_number','floor','center_distance', 'weekday_placement', 'month_placement', 'year_placement','last_price']].corr())
# Out:
#                    rooms_number  floor  center_distance  weekday_placement  \
# rooms_number               1.00  -0.14            -0.17              -0.01
# floor                     -0.14   1.00             0.21               0.06
# center_distance           -0.17   0.21             1.00              -0.00
# weekday_placement         -0.01   0.06            -0.00               1.00
# month_placement            0.02   0.02            -0.04               0.03
# year_placement            -0.05  -0.01             0.04               0.01
# last_price                 0.45   0.13            -0.13               0.03
#
#                    month_placement  year_placement  last_price
# rooms_number                  0.02           -0.05        0.45
# floor                         0.02           -0.01        0.13
# center_distance              -0.04            0.04       -0.13
# weekday_placement             0.03            0.01        0.03
# ...

# %%
pd.plotting.scatter_matrix(data_center[['rooms_number','floor','center_distance','weekday_placement', 'month_placement', 'year_placement', 'last_price']],figsize=(15,15))
plt.show()

# %% [markdown]
# *Вывод:* Проанализированы данные квартир, находящихся в радиусе 6 км от центра Санкт-Петербурга.
# Относительно всех объявлений виден количественный перевес 2-комнатных квартир
# Цена также полностью не зависит ни от одного из параметров, как и в сравнении по всей выборке.

# %% [markdown]
# <div class="alert alert-success">
# <b>✅ Комментарий ревьюера :</b>
#
# С оценкой центральной зоны согласен.
# </div>

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# После тщательной предобработки данных (избавления от пропусков, удаления выбросов) удалось получить следующие итоги:
# 1. Цена зависит премущественно от общей площади и количества комнат.
# 2. Подавляющее большинство квартир имеют высоту потолка не более 2.2 метра.
# 3. Чаще всего продаются 1-комнатные и 2-комнатные квартиры
# 4. Объекты недвижимости продаются в течение 73-120 дней
# 5. В центре Санкт-Петербурга общая площадь меньше влияет на цену, чем количество комнат. В общем сравнении общая площадь влияет на итоговую стоимость квартиры.

# %% [markdown]
# <div class="alert alert-success">
# <b>✅ Комментарий ревьюера :</b>
#
# Общий вывод принят.
# </div>

# %% [markdown]
# ## Чек-лист готовности проекта
#
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  открыт файл
# - [x]  файлы изучены (выведены первые строки, метод info())
# - [x]  определены пропущенные значения
# - [x]  заполнены пропущенные значения
# - [x]  есть пояснение, какие пропущенные значения обнаружены
# - [x]  изменены типы данных
# - [x]  есть пояснение, в каких столбцах изменены типы и почему
# - [x]  посчитано и добавлено в таблицу: цена квадратного метра
# - [x]  посчитано и добавлено в таблицу: день недели, месяц и год публикации объявления
# - [x]  посчитано и добавлено в таблицу: этаж квартиры; варианты — первый, последний, другой
# - [x]  посчитано и добавлено в таблицу: соотношение жилой и общей площади, а также отношение площади кухни к общей
# - [x]  изучены следующие параметры: площадь, цена, число комнат, высота потолков
# - [x]  построены гистограммы для каждого параметра
# - [x]  выполнено задание: "Изучите время продажи квартиры. Постройте гистограмму. Посчитайте среднее и медиану. Опишите, сколько обычно занимает продажа. Когда можно считать, что продажи прошли очень быстро, а когда необычно долго?"
# - [x]  выполнено задание: "Уберите редкие и выбивающиеся значения. Опишите, какие особенности обнаружили."
# - [x]  выполнено задание: "Какие факторы больше всего влияют на стоимость квартиры? Изучите, зависит ли цена от квадратного метра, числа комнат, этажа (первого или последнего), удалённости от центра. Также изучите зависимость от даты размещения: дня недели, месяца и года. "Выберите 10 населённых пунктов с наибольшим числом объявлений. Посчитайте среднюю цену квадратного метра в этих населённых пунктах. Выделите населённые пункты с самой высокой и низкой стоимостью жилья. Эти данные можно найти по имени в столбце '*locality_name'*. "
# - [x]  выполнено задание: "Изучите предложения квартир: для каждой квартиры есть информация о расстоянии до центра. Выделите квартиры в Санкт-Петербурге (*'locality_name'*). Ваша задача — выяснить, какая область входит в центр. Создайте столбец с расстоянием до центра в километрах: округлите до целых значений. После этого посчитайте среднюю цену для каждого километра. Постройте график: он должен показывать, как цена зависит от удалённости от центра. Определите границу, где график сильно меняется — это и будет центральная зона. "
# - [x]  выполнено задание: "Выделите сегмент квартир в центре. Проанализируйте эту территорию и изучите следующие параметры: площадь, цена, число комнат, высота потолков. Также выделите факторы, которые влияют на стоимость квартиры (число комнат, этаж, удалённость от центра, дата размещения объявления). Сделайте выводы. Отличаются ли они от общих выводов по всему городу?"
# - [x]  в каждом этапе есть выводы
# - [x]  есть общий вывод
